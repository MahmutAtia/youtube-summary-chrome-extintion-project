# %%
# !pip install youtube-transcript-api pytube langchain tiktoken openai

# %%
from langchain.document_loaders import YoutubeLoader

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=QNKhJtQpboU&t=13s&ab_channel=RianDoris", add_video_info=True
)

# %%
text = loader.load()

# %%
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI

# %%
prompt_template = """Write a concise key insigts summary  of the following:
"{text}"
CONCISE SUMMARY:"""
prompt = PromptTemplate.from_template(prompt_template)

.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5fddd085e5f> in <cell line: 4>()
#       2 "{text}"
#       3 CONCISE SUMMARY:"""
# ----> 4 prompt = PromptTemplate.from_template(prompt_template)
#
# NameError: name 'PromptTemplate' is not defined

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-16k")
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Define StuffDocumentsChain
stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")

docs = loader.load()
print(stuff_chain.run(docs))
# Out:
# In this video, Marian DARS, co-founder and CEO of the Flow Research Collective, discusses the importance of active recovery for optimal performance. He explains that allostatic load, the wear and tear on the body and mind from constantly adapting to stress, can hinder productivity and lead to health issues. To clear allostatic load and improve performance, DARS recommends becoming an "executive athlete" by incorporating active recovery into daily routines. He provides examples of active recovery protocols such as breath work, cold therapy, heat therapy, meditation, exercise, and sleep. DARS emphasizes the need to oscillate between exertion and recovery and to live like a lion, fully engaged in work or fully switched off and recovering. By integrating active recovery into daily, weekly, and yearly schedules, individuals can reach new levels of performance.

# %%
t ="""In this video, Marian DARS, co-founder and CEO of the Flow Research Collective, discusses the importance of active recovery for optimal performance. He explains that allostatic load, the wear and tear on the body and mind from constantly adapting to stress, can hinder productivity and lead to health issues. To clear allostatic load and improve performance, DARS recommends becoming an "executive athlete" by incorporating active recovery into daily routines. He provides examples of active recovery protocols such as breath work, cold therapy, heat therapy, meditation, exercise, and sleep. DARS emphasizes the need to oscillate between exertion and recovery and to live like a lion, fully engaged in work or fully switched off and recovering. By integrating active recovery into daily, weekly, and yearly schedules, individuals can reach new levels of performance."""

# %%
len(t.split(" "))
# Out:
# 131
